# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url="https://www.flipkart.com/search?q=iphone+mobile&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_11_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_11_na_na_na&as-pos=1&as-type=RECENT&suggestionId=iphone+mobile%7CMobiles&requestId=e9d8b043-3115-4af6-a0d6-ac98bcd32906&as-backfill=on"

# %%
url_req=requests.get(url)

# %%
url_req.status_code
# Out:
# 200

# %%
print(url_req.text)
# Out:
# <!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.5ffd15.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.
# ...

# %%
soup=BeautifulSoup(url_req.content,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.title
# Out:
# <title>Iphone Mobile- Buy Products Online at Best Price in India - All Categories | Flipkart.com</title>

# %%
soup.title.string
# Out:
# 'Iphone Mobile- Buy Products Online at Best Price in India - All Categories | Flipkart.com'

# %%
soup.div
# Out:
# <div id="container"><div><div class="_1kfTjk"><div class="_1rH5Jn"><div class="_1TmfNK"></div><div class="_2Xfa2_"><div class="_3_C9Hx"><div class="_3qX0zy"><a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a><a class="_21ljIi" href="/plus">Explore<!-- --> <span class="_2FVHGh">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a></div></div><div class="_1cmsER"><form action="/search" class="_2M8cLY header-form-search" method="GET"><div class="col-12-12 _2oO9oE"><div class="_3OO5Xc"><input autocomplete="off" class="_3704LK" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value="iphone mobile"/></div><button class="L0Z3Pu" type="submit"><svg class="" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg">
# ...

# %%
soup.a
# Out:
# <a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a>

# %%
soup.find_all("a")
# Out:
# [<a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a>,
#  <a class="_21ljIi" href="/plus">Explore<!-- --> <span class="_2FVHGh">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a>,
#  <a class="_1_3w1N" href="/account/login?ret=/search%3Fq%3Diphone%2Bmobile%26sid%3Dtyy%252C4io%26as%3Don%26as-show%3Don%26otracker%3DAS_QueryStore_OrganicAutoSuggest_1_11_na_na_na%26otracker1%3DAS_QueryStore_OrganicAutoSuggest_1_11_na_na_na%26as-pos%3D1%26as-type%3DRECENT%26suggestionId%3Diphone%2Bmobile%257CMobiles%26requestId%3De9d8b043-3115-4af6-a0d6-ac98bcd32906%26as-backfill%3Don">Login</a>,
#  <a class="_3-PJz-" href="https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&amp;utm_medium=websitedirect"><span>Become a Seller</span></a>,
# ...

# %%
all_links=soup.find_all("a")
for r in all_links:
    print(r.get('href'))
# Out:
# /
# /plus
# /account/login?ret=/search%3Fq%3Diphone%2Bmobile%26sid%3Dtyy%252C4io%26as%3Don%26as-show%3Don%26otracker%3DAS_QueryStore_OrganicAutoSuggest_1_11_na_na_na%26otracker1%3DAS_QueryStore_OrganicAutoSuggest_1_11_na_na_na%26as-pos%3D1%26as-type%3DRECENT%26suggestionId%3Diphone%2Bmobile%257CMobiles%26requestId%3De9d8b043-3115-4af6-a0d6-ac98bcd32906%26as-backfill%3Don
# https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&utm_medium=websitedirect
# /viewcart?exploreMode=true&preference=FLIPKART
# /mobiles-accessories/pr?sid=tyy&q=iphone+mobile&otracker=categorytree
# /mobiles/pr?sid=tyy,4io&q=iphone+mobile&otracker=categorytree
# /buying-guide/mobiles?sid=tyy,4io&otracker=bg_from_browse_lhs
# /
# /mobiles-accessories/pr?sid=tyy&marketplace=FLIPKART
# /mobiles/pr?sid=tyy,4io&marketplace=FLIPKART
# ...

# %%
all_table = soup.find_all("table")
print(all_table)
# Out:
# []

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <link href="https://rukminim2.flixcart.com" rel="preconnect"/>\n  <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>\n  <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.5ffd15.css" rel="stylesheet"/>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>\n  <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>\n  <meta content="102988293558" property="fb:page_id"/>\n  <meta content="658873552,624500995,100000233612389" property="fb:admins"/>\n  <meta content="noodp" name="robots"/>\n  <link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>\n  <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>\n  <meta content="website" property="og:type"/>\n  <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>\n  <link href="/ap
# ...

# %%
model = soup.findAll('div',{'class':'_4rR01T'})

# %%
model
# Out:
# [<div class="_4rR01T">APPLE iPhone 14 (Midnight, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 (Purple, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 (Starlight, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Midnight, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 Plus (Starlight, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Starlight, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Green, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 (Blue, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Pink, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 Plus (Midnight, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 13 (Blue, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 Plus (Blue, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 11 (White, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 11 (White, 64 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 14 Plus (Purple, 128 GB)</div>,
# ...

# %%
product_name = []
for i in model:
    p=i.text
    product_name.append(p)

# %%
print(product_name)
# Out:
# ['APPLE iPhone 14 (Midnight, 128 GB)', 'APPLE iPhone 14 (Purple, 128 GB)', 'APPLE iPhone 14 (Starlight, 128 GB)', 'APPLE iPhone 13 (Midnight, 128 GB)', 'APPLE iPhone 14 Plus (Starlight, 128 GB)', 'APPLE iPhone 13 (Starlight, 128 GB)', 'APPLE iPhone 13 (Green, 128 GB)', 'APPLE iPhone 14 (Blue, 128 GB)', 'APPLE iPhone 13 (Pink, 128 GB)', 'APPLE iPhone 14 Plus (Midnight, 128 GB)', 'APPLE iPhone 13 (Blue, 128 GB)', 'APPLE iPhone 14 Plus (Blue, 128 GB)', 'APPLE iPhone 11 (White, 128 GB)', 'APPLE iPhone 11 (White, 64 GB)', 'APPLE iPhone 14 Plus (Purple, 128 GB)', 'APPLE iPhone 11 (Black, 128 GB)', 'APPLE iPhone 13 ((PRODUCT)RED, 128 GB)', 'APPLE iPhone 14 ((PRODUCT)RED, 128 GB)', 'APPLE iPhone 12 (White, 128 GB)', 'APPLE iPhone 12 (Green, 128 GB)', 'APPLE iPhone 14 (Blue, 256 GB)', 'APPLE iPhone 14 (Purple, 256 GB)', 'APPLE iPhone 11 (Black, 64 GB)', 'APPLE iPhone 14 (Starlight, 256 GB)']

# %%
len(product_name)
# Out:
# 24

# %%
type(product_name)
# Out:
# list

# %%
model_rating = soup.findAll('div',{'class':'_3LWZlK'})

# %%
model_rating
# Out:
# [<div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
# ...

# %%
product_rating = []
for i in model_rating:
    r=i.text
    product_rating.append(r)

# %%
product_rating
# Out:
# ['4.6',
#  '4.6',
#  '4.6',
#  '4.7',
#  '4.6',
#  '4.7',
#  '4.7',
#  '4.6',
#  '4.7',
#  '4.6',
#  '4.7',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.7',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4',
#  '5',
#  '4.7',
#  '5',
#  '5',
#  '4.6',
#  '5',
#  '2',
#  '4.6',
#  '5',
#  '4',
#  '4.6',
#  '5',
#  '5']

# %%
len(product_rating)
# Out:
# 39

# %%
product_rating = product_rating[:24]
len(product_rating)
# Out:
# 24

# %%
model_price = soup.findAll('div',{'class':'_30jeq3 _1_WHN1'})

# %%
model_price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹68,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹68,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹68,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹59,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹77,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹59,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹59,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹68,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹59,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹77,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹59,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹77,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹44,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹41,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹77,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹44,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹59,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹67,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹58,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹58,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹78,999</div>,
# ...

# %%
product_price = []
for i in model_price:
    price=i.text
    product_price.append(price)

# %%
len(product_price)
# Out:
# 24

# %%
product_rating=product_rating[0:36]

# %%
product_rating
# Out:
# ['4.6',
#  '4.6',
#  '4.6',
#  '4.7',
#  '4.6',
#  '4.7',
#  '4.7',
#  '4.6',
#  '4.7',
#  '4.6',
#  '4.7',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.7',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6',
#  '4.6']

# %%
len(product_rating)
# Out:
# 24

# %%
import pandas as pd

# %%
df={'Productname':product_name,'Price':product_price,'Rating':product_rating}

# %%
df
# Out:
# {'Productname': ['APPLE iPhone 14 (Midnight, 128 GB)',
#   'APPLE iPhone 14 (Purple, 128 GB)',
#   'APPLE iPhone 14 (Starlight, 128 GB)',
#   'APPLE iPhone 13 (Midnight, 128 GB)',
#   'APPLE iPhone 14 Plus (Starlight, 128 GB)',
#   'APPLE iPhone 13 (Starlight, 128 GB)',
#   'APPLE iPhone 13 (Green, 128 GB)',
#   'APPLE iPhone 14 (Blue, 128 GB)',
#   'APPLE iPhone 13 (Pink, 128 GB)',
#   'APPLE iPhone 14 Plus (Midnight, 128 GB)',
#   'APPLE iPhone 13 (Blue, 128 GB)',
#   'APPLE iPhone 14 Plus (Blue, 128 GB)',
#   'APPLE iPhone 11 (White, 128 GB)',
#   'APPLE iPhone 11 (White, 64 GB)',
#   'APPLE iPhone 14 Plus (Purple, 128 GB)',
#   'APPLE iPhone 11 (Black, 128 GB)',
#   'APPLE iPhone 13 ((PRODUCT)RED, 128 GB)',
#   'APPLE iPhone 14 ((PRODUCT)RED, 128 GB)',
#   'APPLE iPhone 12 (White, 128 GB)',
#   'APPLE iPhone 12 (Green, 128 GB)',
#   'APPLE iPhone 14 (Blue, 256 GB)',
#   'APPLE iPhone 14 (Purple, 256 GB)',
#   'APPLE iPhone 11 (Black, 64 GB)',
# ...

# %%
data=pd.DataFrame(df)

# %%
data
# Out:
#                                  Productname    Price Rating
# 0         APPLE iPhone 14 (Midnight, 128 GB)  ₹68,999    4.6
# 1           APPLE iPhone 14 (Purple, 128 GB)  ₹68,999    4.6
# 2        APPLE iPhone 14 (Starlight, 128 GB)  ₹68,999    4.6
# 3         APPLE iPhone 13 (Midnight, 128 GB)  ₹59,999    4.7
# 4   APPLE iPhone 14 Plus (Starlight, 128 GB)  ₹77,999    4.6
# 5        APPLE iPhone 13 (Starlight, 128 GB)  ₹59,999    4.7
# 6            APPLE iPhone 13 (Green, 128 GB)  ₹59,999    4.7
# 7             APPLE iPhone 14 (Blue, 128 GB)  ₹68,999    4.6
# 8             APPLE iPhone 13 (Pink, 128 GB)  ₹59,999    4.7
# 9    APPLE iPhone 14 Plus (Midnight, 128 GB)  ₹77,999    4.6
# 10            APPLE iPhone 13 (Blue, 128 GB)  ₹59,999    4.7
# 11       APPLE iPhone 14 Plus (Blue, 128 GB)  ₹77,999    4.6
# 12           APPLE iPhone 11 (White, 128 GB)  ₹44,999    4.6
# 13            APPLE iPhone 11 (White, 64 GB)  ₹41,999    4.6
# ...
